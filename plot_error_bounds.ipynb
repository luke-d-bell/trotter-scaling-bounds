# %%
# import relevant Python packages
import os
import sys
from importlib import reload

# locate directory containing scripts 
current_directory = os.getcwd() 
src_directory = current_directory + '/src'
sys.path.append(src_directory)

# import custom modules
import spin_data
import VTA_data

# reload custom modules (used when modifying scripts)
reload(spin_data)
reload(VTA_data);

# %%
N_qubits = 4
Jx = 1
Jy = 1
Jz = 1
periodic_bc = True 
tolerance = 1e-12
α_start = 0 
α_end = 0.25
α_steps = 100

α_array, ϵ_array, B_array = VTA_data.plot_error_bounds(N_qubits, Jx, Jy, Jz, periodic_bc, \
                                                       tolerance, α_start, α_end, α_steps)

# %%
pwd()
# Out:
# '/Users/lukebell/Documents/boson_gang/trotter-scaling-bounds'
